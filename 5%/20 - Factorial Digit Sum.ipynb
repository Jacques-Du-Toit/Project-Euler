# %% [markdown]
# ![image.png](attachment:dc54686e-dd55-4514-88a9-ae2bd01d074c.png)

# %%
def factorial(n):
    total = 1
    for num in range(1, n+1):
        total *= num
    return total

# %%
sum([int(dig) for dig in str(factorial(100))])
# Out:
# 648
