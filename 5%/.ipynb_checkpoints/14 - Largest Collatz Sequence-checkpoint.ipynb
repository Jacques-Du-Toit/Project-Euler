# %% [markdown]
# ![image.png](attachment:5ec1da71-03e4-4967-ad9a-1570f5e63a51.png)

# %%
def next_term(n):
    if n%2 == 0: return n/2
    else: return 3*n + 1

# %%
c = {3:1,
    5:2}
c.add({1:7})

# %%
print(c.update({1:7}))
# Out:
# None

# %%
g = 1

# %%
a = g.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a = g.copy()
#
# AttributeError: 'int' object has no attribute 'copy'

# %%
def check_sequence_length(start, all_term_lengths):
    n = start
    len_terms = 0
    while True:
        if n in all_term_lengths:
            term_chain_length = len_terms + all_term_lengths[n]
            if len_terms > 0:
                all_terms.update({start: term_chain_length})
            return term_chain_length, all_term_lengths
        
        len_terms += 1
        
        if n == 1:
            return len_terms, all_terms_tried
        next = next_term(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 def check_sequence_length(start: int, all_terms_tried: list[int]) -> Tuple[int, List[int]]:
#       2     pass
#
# NameError: name 'Tuple' is not defined

# %%
longest_chain_length = 0
longest_chain_start = 1
for n in range(1_000_000):
    
    next_term()
